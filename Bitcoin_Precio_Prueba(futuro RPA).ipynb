# %% [markdown]
# # BITCOIN ANALISÍS
# ## Prueba y aprendizaje para hacer Futuro RPA
# Es esta jupyter se busca aprender como analizar una criptomoneda para después hacer un análisis automático de cualquier criptomonedaque se actualice solo, para poder hacer short-term investments y crear un portafolio efectivo a corto plazo. El análisis se hace y queda a discreción del inversor usarlo, se recomienda salirse de la inversión una vez llegado el objetivo debido a la volatibilidad de las criptomonedas.
#
# #### 1 Información
# Toda la info se consigue de yahoo finance

# %%
# Se importan las librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# 2) se Filtra por bitcoin

# %%
data = pd.read_csv('BTC-USD.csv', date_parser = True)
data.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 178  2021-05-28  38507.082031  38856.968750  34779.039063  35697.605469
# 179  2021-05-29  35684.156250  37234.500000  33693.929688  34616.066406
# 180  2021-05-30  34607.406250  36400.667969  33520.738281  35678.128906
# 181  2021-05-31  35658.593750  37468.250000  34241.945313  37332.855469
# 182  2021-06-01  37594.101563  37830.679688  36610.621094  36927.785156
#
#         Adj Close       Volume
# 178  35697.605469  55200191952
# 179  34616.066406  45231013335
# 180  35678.128906  31646080921
# 181  37332.855469  39009847639
# 182  36927.785156  38051725312

# %% [markdown]
# 3) Ahora se entrenan los datos

# %%
data_training = data[data['Date']< '2021-06-01'].copy()
data_training
# Out:
#            Date          Open          High           Low         Close  \
# 0    2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
# 1    2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 2    2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 3    2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
# 4    2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
# ..          ...           ...           ...           ...           ...
# 177  2021-05-27  39316.890625  40379.617188  37247.902344  38436.968750
# 178  2021-05-28  38507.082031  38856.968750  34779.039063  35697.605469
# 179  2021-05-29  35684.156250  37234.500000  33693.929688  34616.066406
# 180  2021-05-30  34607.406250  36400.667969  33520.738281  35678.128906
# 181  2021-05-31  35658.593750  37468.250000  34241.945313  37332.855469
#
#         Adj Close       Volume
# 0    18802.998047  49633658712
# 1    19201.091797  37387697139
# ...

# %% [markdown]
# 4) data test

# %%
data_test = data[data['Date']< '2021-06-01'].copy()
data_test
# Out:
#            Date          Open          High           Low         Close  \
# 0    2020-12-01  19633.769531  19845.974609  18321.921875  18802.998047
# 1    2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 2    2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 3    2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
# 4    2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
# ..          ...           ...           ...           ...           ...
# 177  2021-05-27  39316.890625  40379.617188  37247.902344  38436.968750
# 178  2021-05-28  38507.082031  38856.968750  34779.039063  35697.605469
# 179  2021-05-29  35684.156250  37234.500000  33693.929688  34616.066406
# 180  2021-05-30  34607.406250  36400.667969  33520.738281  35678.128906
# 181  2021-05-31  35658.593750  37468.250000  34241.945313  37332.855469
#
#         Adj Close       Volume
# 0    18802.998047  49633658712
# 1    19201.091797  37387697139
# ...

# %% [markdown]
# 5) Filtramos los datos

# %%
 training_data = data_training.drop(['Date', 'Adj Close'], axis = 1)
 training_data.head()
# Out:
#            Open          High           Low         Close       Volume
# 0  19633.769531  19845.974609  18321.921875  18802.998047  49633658712
# 1  18801.744141  19308.330078  18347.718750  19201.091797  37387697139
# 2  19205.925781  19566.191406  18925.785156  19445.398438  31930317405
# 3  19446.966797  19511.404297  18697.193359  18699.765625  33872388058
# 4  18698.384766  19160.449219  18590.193359  19154.230469  27242455064

# %% [markdown]
# 6) ahora se normaliza los datos para poder ser medidos

# %%
#MinMaxScaler is used to normalize the data
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data
# Out:
# array([[0.03480019, 0.03385628, 0.01575236, 0.01637366, 0.08468948],
#        [0.01650283, 0.02231752, 0.0163309 , 0.02513365, 0.04749206],
#        [0.02539133, 0.02785166, 0.0292951 , 0.03050958, 0.03091513],
#        [0.03069214, 0.02667584, 0.02416851, 0.01410205, 0.03681422],
#        [0.01422982, 0.01914375, 0.02176884, 0.02410247, 0.01667563],
#        [0.02425336, 0.02408103, 0.0286696 , 0.02830299, 0.01075647],
#        [0.02840861, 0.02453876, 0.02941525, 0.02492546, 0.01562435],
#        [0.02507473, 0.02178416, 0.01458669, 0.00577055, 0.03019211],
#        [0.00592809, 0.00767985, 0.00708719, 0.01089265, 0.03847874],
#        [0.01103918, 0.00611327, 0.00756976, 0.00453493, 0.01152605],
#        [0.00467557, 0.        , 0.        , 0.        , 0.0187326 ],
#        [0.        , 0.01397366, 0.00956522, 0.01638815, 0.        ],
#        [0.01661326, 0.02388863, 0.02500141, 0.02384177, 0.01123243],
#        [0.02404032, 0.02224819, 0.03124453, 0.02613603, 0.00219132],
# ...

# %% [markdown]
# 7) Ahora se inician los dos vectores con los que se logrará medir y usar todo

# %%
X_train = [] 
Y_train = []

# %% [markdown]
# 8) Se cuenta para ver cuanto es N

# %%
training_data.shape[0]
# Out:
# 182

# %% [markdown]
# 9) Se hace un for para hacer el análisis y nos permitirá hacer las graficas mediante un vector

# %%
for i in range(182, training_data.shape[0]):
    X_train.append(training_data[i-182:i])
    Y_train.append(training_data[i,0])
    
X_train, Y_train = np.array(X_train), np.array(Y_train)
X_train.shape
# Out:
# (0,)

# %% [markdown]
# Importamos la librería

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-781afef575ec> in <module>
# ----> 1 from tensorflow.keras import Sequential
#       2 from tensorflow.keras.layers import Dense, LSTM, Dropout
#       3 model = Sequential()
#
# ModuleNotFoundError: No module named 'tensorflow'
